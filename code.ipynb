# %%
#importing
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
data=pd.DataFrame(pd.read_csv("weatherHistory.csv"))
data
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
data=data.drop(['Formatted Date','Visibility (km)','Daily Summary','Loud Cover','Pressure (millibars)',
               'Apparent Temperature (C)','Wind Speed (km/h)', 'Wind Bearing (degrees)'],axis=1)
data.head()
# Out:
#          Summary Precip Type  Temperature (C)  Humidity
# 0  Partly Cloudy        rain         9.472222      0.89
# 1  Partly Cloudy        rain         9.355556      0.86
# 2  Mostly Cloudy        rain         9.377778      0.89
# 3  Partly Cloudy        rain         8.288889      0.83
# 4  Mostly Cloudy        rain         8.755556      0.83

# %%
l=LabelEncoder()
data['Summary']=l.fit_transform(data['Summary'])
data['Precip Type']=l.fit_transform(data['Precip Type'])
data.head()
# Out:
#    Summary  Precip Type  Temperature (C)  Humidity
# 0       19            0         9.472222      0.89
# 1       19            0         9.355556      0.86
# 2       17            0         9.377778      0.89
# 3       19            0         8.288889      0.83
# 4       17            0         8.755556      0.83

# %%
print("Missing values in data:\n",data.isnull().sum())
# Out:
# Missing values in data:
#  Summary            0
# Precip Type        0
# Temperature (C)    0
# Humidity           0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Summary', 'Precip Type', 'Temperature (C)', 'Humidity'], dtype='object')

# %%
x=data[['Precip Type', 'Temperature (C)','Humidity']]
y=data['Summary']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([16.94968435, 15.92241261, 16.2843518 , ..., 16.52836713,
#        15.89508552, 16.18121225])

# %%
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
print("mse=",mse)
print("mae=",mae)
print("r2=",r2)
# Out:
# mse= 18.541655487339735
# mae= 3.1442005756547418
# r2= 0.0248181883074563
